# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraisikli/-Clustering-Gaussian-Mixtures-with-AIC-BIC-Sample-Splitting-Cross-Validation-and-Wasserstein/blob/main/COLLECT_NEGATIVE_WORDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **COLLECT NEGATIVE WORDS**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **AFINN**

# %%
allAfinn = pd.read_csv("/content/AFINN-111.txt", delimiter = "\t", names= ['word','sentiment'])

# %%
allAfinn[allAfinn.select_dtypes(include=[np.number]).lt(0).all(1)]

# %%
afinnM1= allAfinn[allAfinn.select_dtypes(include=[np.number]).eq(-1).all(1)]
afinnM2= allAfinn[allAfinn.select_dtypes(include=[np.number]).eq(-2).all(1)]
afinnM3= allAfinn[allAfinn.select_dtypes(include=[np.number]).eq(-3).all(1)]
afinnM4= allAfinn[allAfinn.select_dtypes(include=[np.number]).eq(-4).all(1)]
afinnM5= allAfinn[allAfinn.select_dtypes(include=[np.number]).eq(-5).all(1)]

# %% [markdown]
# **Harvard IV-4**

# %% [markdown]
# **Harvard IV-4 categories**
#
#
# **Ngtv** 1160 negative words
#
# A subset of 833 words are also tagged **Hostile** for words indicating an attitude or concern with hostility or aggressiveness.
#
# **Strong** 1902 words implying strength.
#
# A subset of 689 words are tagged **Power**, indicating a concern with power, control or authority.
#
# **Weak** 755 words implying weakness.
#
# A subset of 284 words are also tagged Submit, connoting submission to authority or power, dependence on others, vulnerability to others, or withdrawal.
#
# **Active** 2045 words implying an active orientation.
#
# **Passive** 911 words indicating a passive orientation
#
#
# **Econ@** 510 words of an economic, commercial, industrial, or business orientation, including roles, collectivities, acts, abstract ideas, and symbols, including references to money. Includes names of common commodities in business.
#
# **Exch** 60 words concerned with buying, selling and trading.
#
# There is also a related ECON category with 502 words (269 in common with Econ@) that is used by the General Inquirer in disambiguating.
#
# **Exprsv** 205 words associated with the arts, sports, and self-expression.
# **Legal** 192 words relating to legal, judicial, or police matters.
# **Milit** 88 words relating to military matters.
# **Polit@** 263 words having a clear political character, including political roles, collectivities, acts, ideas, ideologies, and symbols.
# **Relig** 103 words pertaining to religious, metaphysical, supernatural or relevant philosophical matters.

# %%
inquirerbasic = pd.read_csv("/content/inquirerbasic.csv")

# %%
inquirerbasic_negativ=inquirerbasic[inquirerbasic['Negativ'].isin(['Negativ'])]
inquirerbasic_negativ=inquirerbasic_negativ.drop(columns=['Positiv', 'Source','Pstv','Affil','Ngtv'])

# %%
inquirerbasic_negativ
# Out:
#              Entry  Negativ  Hostile Strong  ... TimeSpc FormLw Othtags Defined
# 1          ABANDON  Negativ      NaN    NaN  ...     NaN    NaN    SUPV       |
# 2      ABANDONMENT  Negativ      NaN    NaN  ...     NaN    NaN    Noun       |
# 3            ABATE  Negativ      NaN    NaN  ...     NaN    NaN    SUPV       |
# 5         ABDICATE  Negativ      NaN    NaN  ...     NaN    NaN    SUPV       |
# 6            ABHOR  Negativ  Hostile    NaN  ...     NaN    NaN    SUPV       |
# ...            ...      ...      ...    ...  ...     ...    ...     ...     ...
# 11730     WRONGFUL  Negativ      NaN    NaN  ...     NaN    NaN   Modif       |
# 11732      WROUGHT  Negativ      NaN    NaN  ...     NaN    NaN   Modif       |
# 11739         YAWN  Negativ      NaN    NaN  ...     NaN    NaN    SUPV       |
# 11745        YEARN  Negativ      NaN    NaN  ...     NaN    NaN    SUPV       |
# 11749         YELP  Negativ      NaN    NaN  ...     NaN    NaN    SUPV       |
#
# ...

# %%
inquirerbasic_negativ_power=inquirerbasic_negativ[inquirerbasic['Power'].isin(['Power'])]
inquirerbasic_negativ_weak=inquirerbasic_negativ[inquirerbasic['Weak'].isin(['Weak'])]
inquirerbasic_negativ_active=inquirerbasic_negativ[inquirerbasic['Active'].isin(['Active'])]
inquirerbasic_negativ_passive=inquirerbasic_negativ[inquirerbasic['Passive'].isin(['Passive'])]

# %%
inquirerbasic_negativ_hostile=inquirerbasic_negativ[inquirerbasic['Hostile'].isin(['Hostile'])] 
inquirerbasic_negativ_econ =inquirerbasic_negativ[inquirerbasic['Econ@'].isin(['Econ@'])]

# %%
inquirerbasic_negativ_passive
# Out:
#           Entry  Negativ  ... Othtags                                     Defined
# 3         ABATE  Negativ  ...    SUPV                                           |
# 5      ABDICATE  Negativ  ...    SUPV                                           |
# 6         ABHOR  Negativ  ...    SUPV                                           |
# 9        ABJECT  Negativ  ...   Modif                                           |
# 34     ABSENT#1  Negativ  ...   Modif                                           |
# ...         ...      ...  ...     ...                                         ...
# 11691   WORRY#4  Negativ  ...   Modif               | 29% adj: "Worried"--anxious
# 11692   WORRY#5  Negativ  ...      LY  | 0% adv: "Worriedly"--in a worried manner
# 11694    WORSEN  Negativ  ...    SUPV                                           |
# 11711   WOUND#5  Negativ  ...   Modif               | 18% adj: "Wounded"--injured
# ...

# %%
inquirerbasic_negativ_active
# Out:
#          Entry  Negativ  Hostile  Strong  ... TimeSpc FormLw Othtags Defined
# 13     ABOLISH  Negativ  Hostile  Strong  ...     NaN    NaN    SUPV       |
# 32     ABSCOND  Negativ  Hostile     NaN  ...     NaN    NaN    SUPV       |
# 52     ABUSE#1  Negativ  Hostile     NaN  ...     NaN    NaN    Noun       |
# 53     ABUSE#2  Negativ  Hostile  Strong  ...     NaN    NaN    SUPV       |
# 86      ACCOST  Negativ  Hostile     NaN  ...     NaN    NaN    SUPV       |
# ...        ...      ...      ...     ...  ...     ...    ...     ...     ...
# 11716  WRESTLE  Negativ  Hostile     NaN  ...     NaN    NaN    SUPV       |
# 11717   WRETCH  Negativ      NaN     NaN  ...     NaN    NaN    SUPV       |
# 11724   WRITHE  Negativ      NaN     NaN  ...     NaN    NaN    SUPV       |
# 11745    YEARN  Negativ      NaN     NaN  ...     NaN    NaN    SUPV       |
# 11749     YELP  Negativ      NaN     NaN  ...     NaN    NaN    SUPV       |
#
# [568 rows x 181 columns]

# %%
inquirerbasic_negativ_weak
# Out:
#              Entry  Negativ  ... Othtags                                     Defined
# 1          ABANDON  Negativ  ...    SUPV                                           |
# 2      ABANDONMENT  Negativ  ...    Noun                                           |
# 5         ABDICATE  Negativ  ...    SUPV                                           |
# 9           ABJECT  Negativ  ...   Modif                                           |
# 32         ABSCOND  Negativ  ...    SUPV                                           |
# ...            ...      ...  ...     ...                                         ...
# 11691      WORRY#4  Negativ  ...   Modif               | 29% adj: "Worried"--anxious
# 11692      WORRY#5  Negativ  ...      LY  | 0% adv: "Worriedly"--in a worried manner
# 11694       WORSEN  Negativ  ...    SUPV                                           |
# 11709      WOUND#3  Negativ  ...    Noun  | 25% noun: A physical or Emotional injury
# ...

# %%
inquirerbasic_negativ_power
# Out:
#                Entry  ...                                            Defined
# 13           ABOLISH  ...                                                  |
# 193         ADMONISH  ...                                                  |
# 646         ARREST#1  ...  | 15% noun-adj: Halting, seizure, usually by l...
# 651        ARROGANCE  ...                                                  |
# 816         AUTOCRAT  ...                                                  |
# ...              ...  ...                                                ...
# 10897        TYRANNY  ...                                                  |
# 11111      UNWILLING  ...                                                  |
# 11112  UNWILLINGNESS  ...                                                  |
# 11166          USURP  ...                                                  |
# 11250           VETO  ...                                                  |
#
# [145 rows x 181 columns]

# %%
inquirerbasic_negativ_econ
# Out:
#               Entry  ...                                            Defined
# 926        BANKRUPT  ...                                                  |
# 927      BANKRUPTCY  ...                                                  |
# 1028         BEGGAR  ...                                                  |
# 1139      BLACKMAIL  ...                                                  |
# 1331          BRIBE  ...                                                  |
# 1359        BROKE#3  ...                          | 3% adjective: Destitute
# 1403            BUM  ...                                                  |
# 1685          CHEAP  ...                                                  |
# 1993       COMMONER  ...                                                  |
# 2366        CORRUPT  ...                                                  |
# 2370         COST#1  ...  | 67% noun-adj: Expense, outlay, sacrifice, lo...
# ...

# %%
inquirerbasic_negativ_hostile
# Out:
#           Entry  ...                                       Defined
# 6         ABHOR  ...                                             |
# 13      ABOLISH  ...                                             |
# 29     ABRASIVE  ...                                             |
# 32      ABSCOND  ...                                             |
# 37     ABSENTEE  ...                                             |
# ...         ...  ...                                           ...
# 11707   WOUND#1  ...  | 46% verb: Physically or Emotionally injure
# 11713     WRATH  ...                                             |
# 11715     WRECK  ...                                             |
# 11716   WRESTLE  ...                                             |
# 11728   WRONG#2  ...  | 1% verb: To injure, malign, treat unfairly
#
# [739 rows x 181 columns]

# %%
inquirerbasic_negativ.to_csv('/content/inquirerbasic_negativ.csv', index=False)

# %% [markdown]
# **Loughran&McDonald**

# %%
contraining= pd.read_csv("/content/LoughranMcDonald_SentimentWordLists_2018 _const.csv", delimiter = "\t", names= ['word'])
weakModal = pd.read_csv("/content/LoughranMcDonald_SentimentWordLists_2018 _weak.csv", delimiter = "\t", names= ['word'])
litigious = pd.read_csv("/content/LoughranMcDonald_SentimentWordLists_2018_liti.csv", delimiter = "\t", names= ['word'])
negative= pd.read_csv("/content/LoughranMcDonald_SentimentWordLists_2018_negative.csv", delimiter = "\t", names= ['word'])
strongModal= pd.read_csv("/content/LoughranMcDonald_SentimentWordLists_2018_strongmodal.csv", delimiter = "\t", names= ['word'])
uncertainty= pd.read_csv("/content/LoughranMcDonald_SentimentWordLists_2018_unc.csv", delimiter = "\t", names= ['word'])

# %%
contraining
# Out:
#                word
# 0             ABIDE
# 1           ABIDING
# 2             BOUND
# 3           BOUNDED
# 4            COMMIT
# ..              ...
# 179        STRICTER
# 180       STRICTEST
# 181        STRICTLY
# 182  UNAVAILABILITY
# 183     UNAVAILABLE
#
# [184 rows x 1 columns]

# %%
strongModal
# Out:
#               word
# 0           ALWAYS
# 1             BEST
# 2          CLEARLY
# 3       DEFINITELY
# 4     DEFINITIVELY
# 5          HIGHEST
# 6           LOWEST
# 7             MUST
# 8            NEVER
# 9         STRONGLY
# 10   UNAMBIGUOUSLY
# 11  UNCOMPROMISING
# 12      UNDISPUTED
# 13     UNDOUBTEDLY
# 14     UNEQUIVOCAL
# 15   UNEQUIVOCALLY
# 16    UNPARALLELED
# 17     UNSURPASSED
# 18            WILL

# %%
weakModal
# Out:
#             word
# 0         ALMOST
# 1     APPARENTLY
# 2       APPEARED
# 3      APPEARING
# 4        APPEARS
# 5    CONCEIVABLE
# 6          COULD
# 7         DEPEND
# 8       DEPENDED
# 9      DEPENDING
# 10       DEPENDS
# 11           MAY
# 12         MAYBE
# 13         MIGHT
# 14        NEARLY
# 15  OCCASIONALLY
# 16       PERHAPS
# 17      POSSIBLE
# 18      POSSIBLY
# 19        SELDOM
# 20      SELDOMLY
# 21     SOMETIMES
# 22      SOMEWHAT
# 23       SUGGEST
# 24      SUGGESTS
# 25     UNCERTAIN
# 26   UNCERTAINLY

# %%
litigious
# Out:
#                word
# 0    ABOVEMENTIONED
# 1          ABROGATE
# 2         ABROGATED
# 3         ABROGATES
# 4        ABROGATING
# ..              ...
# 899     WILLFULNESS
# 900         WITNESS
# 901       WITNESSES
# 902            WRIT
# 903           WRITS
#
# [904 rows x 1 columns]

# %%
negative
# Out:
#               word
# 0          ABANDON
# 1        ABANDONED
# 2       ABANDONING
# 3      ABANDONMENT
# 4     ABANDONMENTS
# ...            ...
# 2350    WRONGDOING
# 2351   WRONGDOINGS
# 2352      WRONGFUL
# 2353    WRONGFULLY
# 2354       WRONGLY
#
# [2355 rows x 1 columns]

# %%
uncertainty
# Out:
#              word
# 0        ABEYANCE
# 1       ABEYANCES
# 2          ALMOST
# 3      ALTERATION
# 4     ALTERATIONS
# ..            ...
# 292          VARY
# 293       VARYING
# 294      VOLATILE
# 295  VOLATILITIES
# 296    VOLATILITY
#
# [297 rows x 1 columns]
